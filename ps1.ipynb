# %% [markdown]
# <a href="https://colab.research.google.com/github/aig48/GIS/blob/main/ps1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %%capture
# !pip install geopandas==1.0.1
# !pip install mapclassify

# %%
import os, zipfile #basics
import pandas as pd #data management
import matplotlib.pyplot as plt #vis

import geopandas as gpd #gis/maps: a sister of pandas; does the job;
#tho not as fancy-interactive as folium or leafmap https://geopandas.org/

import mapclassify #need for thematic map classification

#will display all output not just last command
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

from google.colab import files #to download from colab onto hd

#from google.colab import data_table
#data_table.enable_dataframe_formatter() #this enables spreadsheet view upon calling dataframe (without() )
from google.colab.data_table import DataTable
DataTable.max_columns = 250

# %%
#!python --version
gpd.__version__
# Out:
# '1.0.1'

# %%
#philadelphia
! wget -q -O philadelphia.zip https://www2.census.gov/geo/tiger/TIGER2023/FACES/tl_2023_42101_faces.zip

zip_ref = zipfile.ZipFile('philadelphia.zip', 'r'); zip_ref.extractall(); zip_ref.close() #just unzipping
phl=gpd.read_file('tl_2023_42101_faces.shp') #load the shapefile with gpd as phl

# %%
#make the map
phl.plot()
# Out:
# <Axes: >

# %%
phl.dtypes
# Out:
# TFID             int64
# STATEFP20       object
# COUNTYFP20      object
# TRACTCE20       object
# BLKGRPCE20      object
# BLOCKCE20       object
# SUFFIX1CE       object
# ZCTA5CE20       object
# UACE20          object
# PUMACE20        object
# STATEFP         object
# COUNTYFP        object
# TRACTCE         object
# BLKGRPCE        object
# COUSUBFP        object
# SUBMCDFP        object
# ESTATEFP        object
# CONCTYFP        object
# PLACEFP         object
# AIANNHFP        object
# AIANNHCE        object
# COMPTYP         object
# TRSUBFP         object
# TRSUBCE         object
# ANRCFP          object
# TTRACTCE        object
# TBLKGPCE        object
# ELSDLEA         object
# SCSDLEA         object
# UNSDLEA         object
# SDADMLEA        object
# CD118FP         object
# SLDUST          object
# SLDLST          object
# CSAFP           object
# CBSAFP          object
# METDIVFP        object
# LWFLAG          object
# OFFSET          object
# ATOTAL           int64
# ...

# %%
phl.head(3)
# Out:
#         TFID STATEFP20 COUNTYFP20 TRACTCE20 BLKGRPCE20 BLOCKCE20 SUFFIX1CE  \
# 0  263383227        42        101    980901          1      1007      None
# 1  263383221        42        101    980901          1      1007      None
# 2  263383222        42        101    980901          1      1007      None
#
#   ZCTA5CE20 UACE20 PUMACE20  ... SLDLST CSAFP CBSAFP METDIVFP LWFLAG OFFSET  \
# 0     19153  69076    03229  ...    185   428  37980    37964      L      N
# 1     19153  69076    03229  ...    185   428  37980    37964      L      N
# 2     19153  69076    03229  ...    185   428  37980    37964      L      N
#
#   ATOTAL     INTPTLAT     INTPTLON  \
# 0  26507  +39.8779774  -75.2494657
# 1   2226  +39.8766533  -75.2528084
# 2    769  +39.8770949  -75.2529609
#
#                                             geometry
# 0  POLYGON ((-75.25278 39.87699, -75.25206 39.877...
# 1  POLYGON ((-75.25308 39.87693, -75.25278 39.876...
# ...

# %%
p=phl[('COUNTYFP20','TFID')]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3790         try:
# -> 3791             return self._engine.get_loc(casted_key)
#    3792         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('COUNTYFP20', 'TFID')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-87-d9d38a152a3d> in <cell line: 1>()
# ----> 1 p=phl[('COUNTYFP20','TFID')]
#
# ...

# %%
p.plot()
# Out:
# <Axes: >

# %%
#chester county
! wget -q -O chestercounty.zip https://www2.census.gov/geo/tiger/TIGER2023/FACES/tl_2023_42029_faces.zip

zip_ref = zipfile.ZipFile('chestercounty.zip', 'r'); zip_ref.extractall(); zip_ref.close() #just unzipping
chester=gpd.read_file('tl_2023_42029_faces.shp') #load the shapefile with gpd as chester

# %%
#make the map
chester.plot()
# Out:
# <Axes: >

# %%
chester.dtypes
# Out:
# TFID             int64
# STATEFP20       object
# COUNTYFP20      object
# TRACTCE20       object
# BLKGRPCE20      object
# BLOCKCE20       object
# SUFFIX1CE       object
# ZCTA5CE20       object
# UACE20          object
# PUMACE20        object
# STATEFP         object
# COUNTYFP        object
# TRACTCE         object
# BLKGRPCE        object
# COUSUBFP        object
# SUBMCDFP        object
# ESTATEFP        object
# CONCTYFP        object
# PLACEFP         object
# AIANNHFP        object
# AIANNHCE        object
# COMPTYP         object
# TRSUBFP         object
# TRSUBCE         object
# ANRCFP          object
# TTRACTCE        object
# TBLKGPCE        object
# ELSDLEA         object
# SCSDLEA         object
# UNSDLEA         object
# SDADMLEA        object
# CD118FP         object
# SLDUST          object
# SLDLST          object
# CSAFP           object
# CBSAFP          object
# METDIVFP        object
# LWFLAG          object
# OFFSET          object
# ATOTAL           int64
# ...
